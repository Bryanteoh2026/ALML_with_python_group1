# %% [markdown]
# # ET0737 Telco Customer Churn Prediction
# This notebook runs the same simple Python scripts included in the project folder.

# %% [markdown]
# ## 1. Data cleaning and feature engineering
# The script cleans text values, converts `TotalCharges`, handles new-customer blanks, removes duplicates, and adds two engineered features.

# %%
# %run ../01_data_cleaning.py

# %% [markdown]
# ## 2. Model training, tuning and evaluation
# The script creates a 60/20/20 split, compares four models, tunes Random Forest, selects by validation F1, evaluates the untouched test set and saves all figures.

# %%
# %run ../02_model_training_analysis.py

# %% [markdown]
# ## 3. Customer segmentation
# K-Means creates four customer groups using tenure, charges and optional-service usage. Churn is used only to profile the completed clusters.

# %%
# %run ../03_customer_segmentation.py

# %% [markdown]
# ## 4. Review generated results

# %%
import pandas as pd
display(pd.read_csv('../outputs/model_comparison.csv').round(4))
display(pd.read_csv('../outputs/final_test_metrics.csv').round(4))
display(pd.read_csv('../outputs/customer_segment_summary.csv').round(3))

# %% [markdown]
# ## 5. Website
# Run `python -m streamlit run app.py` from the main project folder, then open `http://localhost:8501`.
